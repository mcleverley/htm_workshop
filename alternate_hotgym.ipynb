# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Cleaning-up-&amp;-recoding-htm.core's-example-&quot;hotgym.py&quot;-so-i-can-figure-out-how-it-works" data-toc-modified-id="Cleaning-up-&amp;-recoding-htm.core's-example-&quot;hotgym.py&quot;-so-i-can-figure-out-how-it-works-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Cleaning up &amp; recoding htm.core's example "hotgym.py" so i can figure out how it works</a></span><ul class="toc-item"><li><span><a href="#default-parameter-dict" data-toc-modified-id="default-parameter-dict-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>default parameter dict</a></span><ul class="toc-item"><li><span><a href="#i'm-gonna-try-to-recode-this-without-&quot;def-main()&quot;-etc" data-toc-modified-id="i'm-gonna-try-to-recode-this-without-&quot;def-main()&quot;-etc-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>i'm gonna try to recode this without "def main()" etc</a></span></li><li><span><a href="#read-input-file" data-toc-modified-id="read-input-file-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>read input file</a></span></li><li><span><a href="#create-Encoder!" data-toc-modified-id="create-Encoder!-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>create Encoder!</a></span></li><li><span><a href="#create-spatial-pooler" data-toc-modified-id="create-spatial-pooler-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>create spatial pooler</a></span></li></ul></li><li><span><a href="#TM-parameter-notes:" data-toc-modified-id="TM-parameter-notes:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>TM parameter notes:</a></span><ul class="toc-item"><li><span><a href="#setup-likelihood-/-anomaly-thresholds" data-toc-modified-id="setup-likelihood-/-anomaly-thresholds-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>setup likelihood / anomaly thresholds</a></span></li><li><span><a href="#iterate-through-dataset,-recording-inputs-&amp;-outputs" data-toc-modified-id="iterate-through-dataset,-recording-inputs-&amp;-outputs-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>iterate through dataset, recording inputs &amp; outputs</a></span></li></ul></li></ul></li><li><span><a href="#alternate-idea:-what-if-we-just-run-a-.learn()-cycle-once-with-no-infer?" data-toc-modified-id="alternate-idea:-what-if-we-just-run-a-.learn()-cycle-once-with-no-infer?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>alternate idea: what if we just run a .learn() cycle once with no infer?</a></span><ul class="toc-item"><li><span><a href="#right,-that-ran.-surprising,-but-it-ran.-shall-we-try-running-the-original-loop-with-the-same-predictor-object-now?" data-toc-modified-id="right,-that-ran.-surprising,-but-it-ran.-shall-we-try-running-the-original-loop-with-the-same-predictor-object-now?-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>right, that ran. surprising, but it ran. shall we try running the original loop with the same predictor object now?</a></span></li></ul></li><li><span><a href="#original-training-loop" data-toc-modified-id="original-training-loop-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>original training loop</a></span></li><li><span><a href="#(1,5)" data-toc-modified-id="(1,5)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>(1,5)</a></span></li><li><span><a href="#SDR-metrics" data-toc-modified-id="SDR-metrics-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>SDR metrics</a></span></li><li><span><a href="#shift-predictions-(currently-causes-div0-crash)" data-toc-modified-id="shift-predictions-(currently-causes-div0-crash)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>shift predictions (currently causes div0 crash)</a></span><ul class="toc-item"><li><span><a href="#alright,-what's-going-on-with-division-by-0-?" data-toc-modified-id="alright,-what's-going-on-with-division-by-0-?-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>alright, what's going on with division by 0 ?</a></span></li><li><span><a href="#1,5-deviation-does-occur,-but-only-at-the-beginning" data-toc-modified-id="1,5-deviation-does-occur,-but-only-at-the-beginning-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>1,5 deviation <em>does</em> occur, but only at the beginning</a></span></li></ul></li><li><span><a href="#pre-fix-graphs:" data-toc-modified-id="pre-fix-graphs:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>pre-fix graphs:</a></span><ul class="toc-item"><li><span><a href="#so-the-accuracy-of-5-steps-and-1-step-versions-almost-immediately-converges." data-toc-modified-id="so-the-accuracy-of-5-steps-and-1-step-versions-almost-immediately-converges.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>so the accuracy of 5-steps and 1-step versions almost immediately converges.</a></span></li><li><span><a href="#the-top-graph-&quot;input&quot;-is-way-below-predicted-values" data-toc-modified-id="the-top-graph-&quot;input&quot;-is-way-below-predicted-values-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>the top graph "input" is <em>way</em> below predicted values</a></span></li></ul></li><li><span><a href="#post-fix-graphs" data-toc-modified-id="post-fix-graphs-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>post-fix graphs</a></span><ul class="toc-item"><li><span><a href="#looks-much-better" data-toc-modified-id="looks-much-better-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>looks much better</a></span></li></ul></li><li><span><a href="#takeaways:" data-toc-modified-id="takeaways:-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>takeaways:</a></span></li><li><span><a href="#end-of-document,-only-code-scraps-below" data-toc-modified-id="end-of-document,-only-code-scraps-below-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>end of document, only code scraps below</a></span><ul class="toc-item"><li><span><a href="#ah,-we're-still-stuck-at-the-same-error-as-before" data-toc-modified-id="ah,-we're-still-stuck-at-the-same-error-as-before-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>ah, we're still stuck at the same error as before</a></span><ul class="toc-item"><li><span><a href="#something's-written-wrong,-i-think---or-i've-installed-something-wrong" data-toc-modified-id="something's-written-wrong,-i-think---or-i've-installed-something-wrong-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>something's written wrong, i think - or i've installed something wrong</a></span></li><li><span><a href="#some-progress:" data-toc-modified-id="some-progress:-10.1.2"><span class="toc-item-num">10.1.2&nbsp;&nbsp;</span>some progress:</a></span></li></ul></li><li><span><a href="#why-do-we-call-predictor.infer(tm_SDR),-then-predictor.learn(count,-TM_SDR,-consumption/predictor_resolution)-at-each-iteration?" data-toc-modified-id="why-do-we-call-predictor.infer(tm_SDR),-then-predictor.learn(count,-TM_SDR,-consumption/predictor_resolution)-at-each-iteration?-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>why do we call predictor.infer(tm_SDR), then predictor.learn(count, TM_SDR, consumption/predictor_resolution) at each iteration?</a></span><ul class="toc-item"><li><span><a href="#because-we're-trying-to-make-a-prediction-on-each-round-to-see-how-well-we-grow-over-time" data-toc-modified-id="because-we're-trying-to-make-a-prediction-on-each-round-to-see-how-well-we-grow-over-time-10.2.1"><span class="toc-item-num">10.2.1&nbsp;&nbsp;</span>because we're trying to make a prediction on each round to see how well we grow over time</a></span><ul class="toc-item"><li><span><a href="#makes-sense.-but" data-toc-modified-id="makes-sense.-but-10.2.1.1"><span class="toc-item-num">10.2.1.1&nbsp;&nbsp;</span>makes sense. but</a></span></li></ul></li></ul></li><li><span><a href="#post-training" data-toc-modified-id="post-training-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>post-training</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Cleaning up & recoding htm.core's example "hotgym.py" so i can figure out how it works
# - some notes on errors:
#     - The training loop crashes on "predictor.infer()", citing a RuntimeError "you must call learn before infer".
#         - i was able to avoid this error by adding an altered copy of the training loop before the original
#         - the altered copy
#         - wait, i forgot that i dropped a 'tm.compute' line in the original somehow
#     - there's a loop designed to shift predictions to align it properly (ctrl-F "div0 crash")
#         - it causes the accuracy calculation to divide by 0. i tried running all this without it and it seems no worries, though. weird
# - the graph doesn't look half bad, but i'm still not entirely sure how that realignment loop works or why it crashes

# %%
import csv
import datetime
import os
import numpy as np
import random
import math

from htm.bindings.sdr import SDR, Metrics
from htm.encoders.rdse import RDSE, RDSE_Parameters
from htm.encoders.date import DateEncoder
from htm.bindings.algorithms import SpatialPooler
from htm.bindings.algorithms import TemporalMemory
from htm.algorithms.anomaly_likelihood import AnomalyLikelihood #FIXME use TM.anomaly instead, but it gives worse results than the py.AnomalyLikelihood now
from htm.bindings.algorithms import Predictor

# %%
cwd = os.getcwd()
input_file_path = cwd+'/gymdata.csv'
input_file_path
# _INPUT_FILE_PATH = os.join(cwd, 'gymdata.csv') # i moved this locally from the example folder
# Out:
# '/Users/mark/Documents/flatiron/projects/htm/htm_nlp_predictive/gymdata.csv'

# %% [markdown]
# ## default parameter dict

# %%
parameters = {
  # there are 2 (3) encoders: "value" (RDSE) & "time" (DateTime weekend, timeOfDay)
 'enc': {
      "value" :
         {'resolution': 0.88, 'size': 700, 'sparsity': 0.02},
      "time": 
         {'timeOfDay': (30, 1), 'weekend': 21}
 },
 'predictor': {'sdrc_alpha': 0.1},
 'sp': {'boostStrength': 3.0,
        'columnCount': 1638,
        'localAreaDensity': 0.04395604395604396,
        'potentialPct': 0.85,
        'synPermActiveInc': 0.04,
        'synPermConnected': 0.13999999999999999,
        'synPermInactiveDec': 0.006},
 'tm': {'activationThreshold': 17,
        'cellsPerColumn': 13,
        'initialPerm': 0.21,
        'maxSegmentsPerCell': 128,
        'maxSynapsesPerSegment': 64,
        'minThreshold': 10,
        'newSynapseCount': 32,
        'permanenceDec': 0.1,
        'permanenceInc': 0.1},
 'anomaly': {
   'likelihood': 
       {#'learningPeriod': int(math.floor(self.probationaryPeriod / 2.0)),
        #'probationaryPeriod': self.probationaryPeriod-default_parameters["anomaly"]["likelihood"]["learningPeriod"],
        'probationaryPct': 0.1,
        'reestimationPeriod': 100} #These settings are copied from NAB
 }
}

# %% [markdown]
# ### i'm gonna try to recode this without "def main()" etc
# - i must explore

# %%
import pprint
print("Parameters:")
pprint.pprint(parameters, indent=4)
# pprint('')
# Out:
# Parameters:
# {   'anomaly': {   'likelihood': {   'probationaryPct': 0.1,
#                                      'reestimationPeriod': 100}},
#     'enc': {   'time': {'timeOfDay': (30, 1), 'weekend': 21},
#                'value': {'resolution': 0.88, 'size': 700, 'sparsity': 0.02}},
#     'predictor': {'sdrc_alpha': 0.1},
#     'sp': {   'boostStrength': 3.0,
#               'columnCount': 1638,
#               'localAreaDensity': 0.04395604395604396,
#               'potentialPct': 0.85,
#               'synPermActiveInc': 0.04,
#               'synPermConnected': 0.13999999999999999,
#               'synPermInactiveDec': 0.006},
#     'tm': {   'activationThreshold': 17,
#               'cellsPerColumn': 13,
#               'initialPerm': 0.21,
#               'maxSegmentsPerCell': 128,
#               'maxSynapsesPerSegment': 64,
#               'minThreshold': 10,
#               'newSynapseCount': 32,
#               'permanenceDec': 0.1,
#               'permanenceInc': 0.1}}

# %% [markdown]
# ### read input file

# %%
records = []
with open(input_file_path, 'r') as fin:
    reader = csv.reader(fin)
    headers = next(reader)
    next(reader)
    next(reader)
    for record in reader:
        records.append(record) # gymdata.csv is just 2 columns
        # dateTime & float(power_consumption)

# %%
# records # list of dateTime, float
# they're coded as strings right now, but no worries

# %% [markdown]
# ### create Encoder!

# %%
parameters['enc']['time']['timeOfDay']
# Out:
# (30, 1)

# %%
parameters["enc"]["time"]["weekend"]
# Out:
# 21

# %%
# ah, these parameters mean "how much SDR_space to allocate each variable"
dateEncoder = DateEncoder(
    timeOfDay = parameters['enc']['time']['timeOfDay'],
    weekend = parameters["enc"]["time"]["weekend"])

# %%
scalarEncoderParams = RDSE_Parameters() # random distributed scalar encoder
scalarEncoderParams.size       = parameters["enc"]["value"]["size"]
scalarEncoderParams.sparsity   = parameters["enc"]["value"]["sparsity"]
scalarEncoderParams.resolution = parameters["enc"]["value"]["resolution"]
scalarEncoder = RDSE(scalarEncoderParams)
encodingWidth = (dateEncoder.size + scalarEncoder.size)
enc_info = Metrics( [encodingWidth], 999999999) # wonder what this 2nd parameter is

# %%
scalarEncoderParams.resolution # ?
# Out:
# 0.8799999952316284

# %% [markdown]
# ### create spatial pooler

# %%
spParams = parameters['sp']

# %%
sp = SpatialPooler(
    inputDimensions            = (encodingWidth,),
    columnDimensions           = (spParams["columnCount"],),
    potentialPct               = spParams["potentialPct"],
    potentialRadius            = encodingWidth,
    globalInhibition           = True,
    localAreaDensity           = spParams["localAreaDensity"],
    synPermInactiveDec         = spParams["synPermInactiveDec"],
    synPermActiveInc           = spParams["synPermActiveInc"],
    synPermConnected           = spParams["synPermConnected"],
    boostStrength              = spParams["boostStrength"],
    wrapAround                 = True
)
sp_info = Metrics(sp.getColumnDimensions(), 999999999)

# %% [markdown]
# there's that "sp.getColumnDimensions()" again. very important method, i guess.

# %%
tmParams = parameters['tm']
tm = TemporalMemory(
    columnDimensions          = (spParams["columnCount"],),
    cellsPerColumn            = tmParams["cellsPerColumn"],
    activationThreshold       = tmParams["activationThreshold"],
    initialPermanence         = tmParams["initialPerm"],
    connectedPermanence       = spParams["synPermConnected"],
    minThreshold              = tmParams["minThreshold"],
    maxNewSynapseCount        = tmParams["newSynapseCount"],
    permanenceIncrement       = tmParams["permanenceInc"],
    permanenceDecrement       = tmParams["permanenceDec"],
    predictedSegmentDecrement = 0.0,
    maxSegmentsPerCell        = tmParams["maxSegmentsPerCell"],
    maxSynapsesPerSegment     = tmParams["maxSynapsesPerSegment"]
)
tm_info = Metrics( [tm.numberOfCells()], 999999999)
# we keep using the 999999999 thing whener we call Metrics(). hmmm

# %% [markdown]
# ## TM parameter notes:
# - cellsPerColumn is very interesting
#     - if we only had 1, there would be no temporal aspect to the memory
#     - each cell beyond 1 allows the TM to recognize state_A from another time-step before it
#     - 4 cells can recognize len=3 state-chains, etc

# %% [markdown]
# ### setup likelihood / anomaly thresholds

# %%
anParams = parameters['anomaly']['likelihood']
probationaryPeriod = int(math.floor(float(anParams['probationaryPct'])*len(records)))
learningPeriod = int(math.floor(probationaryPeriod / 2.0))
anomaly_history = AnomalyLikelihood(learningPeriod = learningPeriod,
       estimationSamples = probationaryPeriod - learningPeriod,
       reestimationPeriod = anParams['reestimationPeriod'])
predictor = Predictor(steps=[1,5], alpha=parameters['predictor']['sdrc_alpha'])
predictor_resolution = 1

# %% [markdown]
# ### iterate through dataset, recording inputs & outputs

# %%
predictor = Predictor(steps=[1,5], alpha=parameters['predictor']['sdrc_alpha'])
predictor_resolution = 1
# changing steps from [1,5] to [1] doesn't fix the learn before infer crash

# %% [markdown]
# right, 'records' is a list that stores strings of dateTime & power-floats.
# - the encoded data is stored... where again?
#     - it's what we're feeding into the SP + TM, so...
#     - isn't it "encoding"?
#         - it's an SDR formed by concatenating the encoded-sdrs of dateString & powerFloat
#         - so this is... yeah, this should be what we feed Predictor.learn()

# %%
records[0][1] # string
# Out:
# '21.2'

# %% [markdown]
# # alternate idea: what if we just run a .learn() cycle once with no infer?

# %%
predictor.reset()
predictor = Predictor(steps=[1,5], alpha=parameters['predictor']['sdrc_alpha'])
predictor_resolution = 1
inputs = []
anomaly = []
anomalyProb = []
predictions = {1: [], 5:[]}
for count, record in enumerate(records): # iterate through listified CSV
    dateString = datetime.datetime.strptime(record[0], '%m/%d/%y %H:%M')
    consumption = float(record[1])
    inputs.append(consumption)
    # encoders at work
    dateBits = dateEncoder.encode(dateString)
    consumptionBits = scalarEncoder.encode(consumption)
    # concatenate these bad boys for a composite x,y input
    encoding = SDR(encodingWidth).concatenate([consumptionBits, dateBits])
    enc_info.addData(encoding) # keep track in metrics
    # create an SDR for active columns, same dimensions as SP
    activeColumns = SDR(sp.getColumnDimensions())
    # hurl input into the pool
    sp.compute(encoding, True, activeColumns)
    tm_info.addData(tm.getActiveCells().flatten())
    # dunno why we add the TM active state before tm.compute(), but i don't know most things
    tm.compute(activeColumns, learn=True)
    # let's change things up and try to just let the predictor learn before making any predictions
    predictor.learn(count, tm.getActiveCells(), int(round(consumption/predictor_resolution)))

# %% [markdown]
# ## right, that ran. surprising, but it ran. shall we try running the original loop with the same predictor object now?

# %%
records[1][1]
# Out:
# '16.4'

# %% [markdown]
# # original training loop

# %%
inputs = []
anomaly = []
anomalyProb = []
predictions = {1: [], 5:[]}
predictor.reset() # this seems like a good idea based on what i know of resets
for count, record in enumerate(records): # iterate through listified CSV
    dateString = datetime.datetime.strptime(record[0], "%m/%d/%y %H:%M") # unstring it
    consumption = float(record[1]) # unstring the power value
    inputs.append(consumption) # add power to input
    
    # use encoder: create SDRs for each input value
    dateBits = dateEncoder.encode(dateString)
    consumptionBits = scalarEncoder.encode(consumption)
    
    # concatenate these encoded_SDRs into a larger one for pooling
    encoding = SDR(encodingWidth).concatenate([consumptionBits, dateBits])
    enc_info.addData(encoding) # enc_info is our metrics to keep track of how the encoder fares
    
    # create SDR to represent active columns. it'll be populated by .compute()
    # notably, this activeColumns SDR has same dimensions as spatial pooler
    activeColumns = SDR(sp.getColumnDimensions())
    
    # throw the input into the spatial pool and hope it swims
    sp.compute(encoding, True, activeColumns) # we're training, so learn=True
    tm_info.addData(tm.getActiveCells().flatten())
    ''''''
    # gonna have to put a predictor.learn in here somewhere, i believe. maybe i'm incorporating it wrong.
#     predictor.learn(count, activeColumns, record[1])
    # make prediction, then train the predictor accordingly
#     learned = predictor.learn(count, encoding, int(round(float(record[1]))))

    # my new position of learn()
#     predictor.learn(4391+count, tm.getActiveCells(), int(consumption/predictor_resolution))
    tm.compute(activeColumns, learn=True)

    pdf = predictor.infer( tm.getActiveCells() )
    for n in (1,5):
        if pdf[n]:
            predictions[n].append( np.argmax( pdf[n] ) * predictor_resolution )
        else:
            predictions[n].append(float('nan'))
    
    anomalyLikelihood = anomaly_history.anomalyProbability( consumption, tm.anomaly )
    anomaly.append(tm.anomaly)
    anomalyProb.append(anomalyLikelihood)
    # original position of learn()
    predictor.learn(count, tm.getActiveCells(), int(consumption/predictor_resolution))
# this runs too, surprisingly.
# used to have an error involving learn()'s first parameter, an int that keeps track of record_count
# when i used the original code instead of my altere learn() position, it's no worries
# this is after running the first no-infer only-learn altered loop copy, however.
old_inputs = inputs # store the inputs because they somehow get normalized later

# %% [markdown]
# out data lists:
#
# - inputs = []
# - anomaly = []
# - anomalyProb = []
# - predictions = {1: [], 5:[]}

# %%
len(inputs) # just a list of all the power_floats in order
np.unique(anomaly) # damn, still only 0 predictions for anomaly...?
# wait, this works now after i added the tm.compute line i forgot in the original loop
# i'm absolutely _peeved_
# Out:
# array([0.        , 0.01388889, 0.02777778, 0.04166667, 0.06944445,
#        0.08333334, 0.09722222, 0.11111111, 0.125     , 0.1388889 ,
#        0.15277778, 0.16666667, 0.18055555, 0.19444445, 0.20833333,
#        0.22222222, 0.2638889 , 0.27777779, 0.29166666, 0.34722221,
#        0.3611111 , 0.375     , 0.3888889 , 0.40277779, 0.41666666,
#        0.43055555, 0.44444445, 0.45833334, 0.4861111 , 0.5       ,
#        0.5138889 , 0.52777779, 0.54166669, 0.59722221, 0.6111111 ,
#        0.68055558, 0.69444442, 0.75      , 0.80555558, 0.90277779,
#        0.95833331])

# %%
np.unique(anomalyProb)
# Out:
# array([0.5       , 0.50924165, 0.50924925, 0.50927115, 0.53199919,
#        0.53213559, 0.53220403, 0.53229223, 0.532465  , 0.55470557,
#        0.55499226, 0.55531739, 0.57496415, 0.57661524, 0.60118007,
#        0.61559112, 0.61634882, 0.61936075, 0.63256783, 0.63438716,
#        0.63438718, 0.63621196, 0.63901059, 0.64059964, 0.641628  ,
#        0.64197748, 0.64288537, 0.64295743, 0.64307037, 0.64312501,
#        0.64321608, 0.64322716, 0.64380074, 0.64384631, 0.64388815,
#        0.644094  , 0.64456185, 0.64466383, 0.64500251, 0.64847654,
#        0.65231497, 0.65250975, 0.65744494, 0.65869721, 0.66141272,
#        0.66257587, 0.66420665, 0.66508363, 0.66513092, 0.66638996,
#        0.66739295, 0.67053242, 0.67485941, 0.67873641, 0.67975281,
#        0.68303158, 0.68580571, 0.68724986, 0.68932201, 0.72178678,
#        0.72891338, 0.73706632, 0.74265958, 0.746848  , 0.75047042,
#        0.76247592, 0.76505753, 0.76600505, 0.76723617, 0.76794773,
#        0.76814671, 0.76828456, 0.78022926, 0.78336237, 0.78378058,
#        0.78441171, 0.78473225, 0.78815625, 0.79865261, 0.79877973,
#        0.80130944, 0.80208916, 0.80711115, 0.80993349, 0.80993349,
#        0.8101379 , 0.81119776, 0.81351977, 0.81563371, 0.82415611,
#        0.82482508, 0.82757172, 0.8276565 , 0.83101354, 0.83265281,
#        0.83332122, 0.83460977, 0.83580198, 0.83608453, 0.83750037,
#        0.83895464, 0.84249605, 0.84336018, 0.84367883, 0.84432586,
#        0.84472942, 0.84532029, 0.84675687, 0.84797832, 0.84847045,
#        0.85016758, 0.85154661, 0.8523188 , 0.8530562 , 0.85358996,
#        0.85415637, 0.85437114, 0.85477776, 0.85525832, 0.85540122,
#        0.85570232, 0.85612422, 0.85671079, 0.85680704, 0.85697501,
#        0.85698685, 0.85733733, 0.85748897, 0.85807389, 0.85932398,
#        0.86009056, 0.86047171, 0.86207393, 0.86215848, 0.8649191 ,
#        0.86555588, 0.86565042, 0.8657661 , 0.86691725, 0.8670863 ,
#        0.86735674, 0.86771483, 0.86797431, 0.86807402, 0.86870669,
#        0.86891074, 0.86893869, 0.86894806, 0.86907387, 0.86927087,
#        0.86936612, 0.86952478, 0.86954407, 0.86959477, 0.86965817,
#        0.87001826, 0.87051393, 0.87053193, 0.87054051, 0.87061948,
#        0.87069195, 0.87180957, 0.8721759 , 0.87250602, 0.87261294,
#        0.87276425, 0.87297087, 0.87318307, 0.87347744, 0.87463196,
#        0.87676166, 0.87683256, 0.87686391, 0.87748278, 0.87855763,
#        0.87916418, 0.87951685, 0.87977235, 0.87987053, 0.88013998,
#        0.88072165, 0.88073087, 0.88085467, 0.88087607, 0.88104851,
#        0.88114223, 0.88123058, 0.88129832, 0.8813173 , 0.88171846,
#        0.88229729, 0.88237493, 0.88244619, 0.88343719, 0.88358967,
#        0.88367798, 0.8839045 , 0.88433375, 0.88434347, 0.88468523,
#        0.885014  , 0.88508987, 0.88510051, 0.88785688, 0.88856401,
#        0.88961748, 0.89021168, 0.89055706, 0.89080725, 0.89090337,
#        0.89173646, 0.89174548, 0.89186662, 0.89205628, 0.89214797,
#        0.89230067, 0.89231923, 0.89327761, 0.89335351, 0.89342317,
#        0.89376542, 0.89439166, 0.89454062, 0.89470909, 0.89472813,
#        0.89484814, 0.89526734, 0.8956105 , 0.89593143, 0.89654151,
#        0.9071413 , 0.91757719, 0.92610304, 0.92827   , 0.92937255,
#        0.93500711, 0.9362297 , 0.93675057, 0.95581565, 0.95906754,
#        0.9613313 , 0.96829509, 0.96981677, 0.9740273 , 0.97419244,
#        0.97626483, 0.97849948, 0.98152489, 0.98300511, 0.98323426,
#        0.9845754 , 0.9851126 , 0.98630354, 0.98692835, 0.98837859,
#        0.98856676, 0.98896847, 0.98975142, 0.9900384 , 0.99063658,
#        0.99079524, 0.99147376, 0.99156913, 0.99171852, 0.99200438,
#        0.99305955, 0.99319332, 0.99356828, 0.99357313, 0.99419055,
#        0.99422412, 0.99435315, 0.99449834, 0.99493834, 0.99506496,
#        0.99515961, 0.99573577, 0.99574892, 0.99599154, 0.99639974,
#        0.99672208, 0.99696109, 0.99699836, 0.99707473, 0.99724802,
#        0.99727559, 0.99734676, 0.9974562 , 0.99749149, 0.99756083,
#        0.99769657, 0.99771222, 0.99782425, 0.99796021, 0.99800343,
#        0.99819881, 0.9990164 , 0.999193  , 0.9994193 , 0.99952151,
#        0.99957026, 0.99958842, 0.99966695, 0.99966703, 0.99973135,
#        0.99995552, 0.99996498, 0.99996923, 0.9999763 ])

# %%
for l in predictions.values():
    print(len(l)) # so we've got 1-step and 5-step versions of each record
# Out:
# 4391
# 4391

# %% [markdown]
# # (1,5)
# - i'm fairly sure now that this 1,5 business is about showing the difference in performance when len(1) and len(5) sequence memories are used
#     - explained by the separation of predictions into a coded dictionary, as well as the length of each list of values

# %% [markdown]
# # SDR metrics
# - these were a lot... 'healthier', i suppose, after i fixed the tm.compute() line i missed
#     - higher ranges of spatial pooler synapses, no "0 and 1 min and max" overlap on any of the parts anymore
#     - hard to describe, but definitely better

# %%
print("Encoded Input", enc_info)
print("")
print("Spatial Pooler Mini-Columns", sp_info)
print(str(sp))
print("")
print("Temporal Memory Cells", tm_info)
print(str(tm))
print("")
# Out:
# Encoded Input SDR( 1462 )
#     Sparsity Min/Mean/Std/Max 0.0437757 / 0.0444322 / 0.00013013 / 0.0444596
#     Activation Frequency Min/Mean/Std/Max 0 / 0.0444337 / 0.0966591 / 0.685265
#     Entropy 0.69568
#     Overlap Min/Mean/Std/Max 0 / 0.442372 / 0.0884816 / 0.538462
#
# Spatial Pooler Mini-Columns SDR( 1638 )
#     Sparsity Min/Mean/Std/Max inf / 1234.57 / 35.1364 / -inf
#     Activation Frequency Min/Mean/Std/Max 1234.57 / 1234.59 / 0.0260008 / 1234.57
#     Entropy 0
#     Overlap Min/Mean/Std/Max inf / 1234.57 / 35.1364 / -inf
# Spatial Pooler Connections:
#     Inputs (1462) ~> Outputs (1638) via Segments (1638)
#     Segments on Cell Min/Mean/Max 1 / 1 / 1
#     Potential Synapses on Segment Min/Mean/Max 1243 / 1243 / 1243
#     Connected Synapses on Segment Min/Mean/Max 58 / 204.905 / 656
#     Synapses Dead (0.741658%) Saturated (0.0346536%)
#     Synapses pruned (0%) Segments pruned (0%)
#     Buffer for destroyed synapses: 0 	 buffer for destr. segments: 0
#
#
# Temporal Memory Cells SDR( 21294 )
#     Sparsity Min/Mean/Std/Max 0 / 0.00437705 / 0.0045907 / 0.043956
#     Activation Frequency Min/Mean/Std/Max 0 / 0.00437706 / 0.00757702 / 0.0341607
#     Entropy 0.841067
#     Overlap Min/Mean/Std/Max 0 / 0.00447824 / 0.0230585 / 0.357798
# Temporal Memory Connections:
#     Inputs (5782) ~> Outputs (21294) via Segments (7985)
#     Segments on Cell Min/Mean/Max 0 / 0.374988 / 2
#     Potential Synapses on Segment Min/Mean/Max 32 / 36.1446 / 64
#     Connected Synapses on Segment Min/Mean/Max 31 / 35.3326 / 63
#     Synapses Dead (0%) Saturated (0.589096%)
#     Synapses pruned (0.670998%) Segments pruned (0%)
#     Buffer for destroyed synapses: 571 	 buffer for destr. segments: 0

# %% [markdown]
# # shift predictions (currently causes div0 crash)
# - i'm sure there's a good alignment reason for this, but it currently causes the accuracy_score loop below to crash on /0
# - this still crashes after i fixed the tm.compute...

# %%
# Shift the predictions so that they are aligned with the input they predict.
for n_steps, pred_list in predictions.items():
    for x in range(n_steps):
        pred_list.insert(0, float('nan'))
        pred_list.pop()

# %%
# predictions
# Out:
# {1: [nan,
#   21,
#   16,
#   4,
#   4,
#   4,
#   23,
#   47,
#   45,
#   46,
#   41,
#   43,
#   43,
#   37,
#   36,
#   35,
#   38,
#   36,
#   36,
#   37,
#   38,
#   14,
#   5,
#   5,
#   5,
#   22,
#   22,
#   6,
#   4,
#   4,
#   4,
#   23,
#   42,
#   52,
#   50,
#   45,
#   43,
#   40,
#   38,
#   39,
#   42,
#   42,
#   28,
#   11,
#   5,
#   5,
#   5,
#   5,
#   13,
#   22,
#   13,
#   5,
#   4,
#   4,
#   5,
#   5,
#   5,
#   42,
#   50,
#   43,
#   37,
#   38,
#   37,
#   40,
#   44,
#   39,
#   26,
#   9,
#   5,
#   5,
#   5,
#   5,
#   17,
#   22,
#   7,
#   4,
#   4,
#   4,
#   22,
#   46,
#   37,
#   38,
#   41,
#   43,
#   44,
#   38,
#   38,
#   37,
#   36,
#   39,
#   38,
#   44,
#   46,
#   38,
#   29,
#   5,
#   10,
#   22,
#   12,
#   4,
#   4,
#   4,
#   22,
#   42,
#   39,
#   38,
#   40,
#   44,
#   41,
#   40,
#   40,
#   39,
#   39,
#   37,
#   40,
#   40,
#   43,
#   36,
#   33,
#   7,
#   6,
#   22,
#   22,
#   12,
#   4,
#   4,
#   22,
#   42,
#   42,
#   39,
#   45,
#   41,
#   41,
#   39,
#   37,
#   40,
#   37,
#   39,
#   40,
#   44,
#   44,
#   36,
#   31,
#   5,
#   15,
#   22,
#   20,
#   4,
#   4,
#   4,
#   22,
#   45,
#   44,
#   39,
#   43,
#   42,
#   44,
#   37,
#   39,
#   35,
#   38,
#   37,
#   40,
#   41,
#   38,
#   38,
#   13,
#   9,
#   22,
#   20,
#   11,
#   4,
#   4,
#   4,
#   22,
#   46,
#   39,
#   38,
#   43,
#   47,
#   43,
#   40,
#   37,
#   39,
#   36,
#   38,
#   38,
#   40,
#   35,
#   15,
#   5,
#   5,
#   4,
#   19,
#   14,
#   4,
#   4,
#   4,
#   4,
#   25,
#   43,
#   41,
#   48,
#   49,
#   42,
#   40,
#   38,
#   43,
#   40,
#   41,
#   30,
#   11,
#   5,
#   5,
#   5,
#   5,
#   4,
#   9,
#   4,
#   4,
#   21,
#   12,
#   4,
#   5,
#   6,
#   31,
#   39,
#   45,
#   39,
#   38,
#   41,
#   40,
#   40,
#   40,
#   28,
#   9,
#   5,
#   5,
#   5,
#   5,
#   17,
#   20,
#   4,
#   4,
#   4,
#   4,
#   19,
#   36,
#   36,
#   37,
#   44,
#   44,
#   43,
#   37,
#   39,
#   41,
#   37,
#   39,
#   43,
#   46,
#   50,
#   42,
#   29,
#   5,
#   11,
#   22,
#   15,
#   4,
#   4,
#   6,
#   18,
#   37,
#   41,
#   37,
#   44,
#   47,
#   47,
#   41,
#   39,
#   40,
#   39,
#   44,
#   42,
#   48,
#   46,
#   43,
#   31,
#   5,
#   9,
#   21,
#   16,
#   4,
#   4,
#   4,
#   11,
#   38,
#   40,
#   39,
#   45,
#   45,
#   47,
#   42,
#   42,
#   45,
#   46,
#   41,
#   42,
#   42,
#   43,
#   39,
#   31,
#   5,
#   8,
#   17,
#   18,
#   4,
#   4,
#   4,
#   18,
#   37,
#   37,
#   40,
#   44,
#   43,
#   43,
#   41,
#   39,
#   43,
#   44,
#   40,
#   41,
#   46,
#   40,
#   39,
#   17,
#   5,
#   4,
#   8,
#   4,
#   5,
#   22,
#   14,
#   22,
#   44,
#   44,
#   39,
#   45,
#   45,
#   42,
#   42,
#   37,
#   41,
#   44,
#   39,
#   40,
#   40,
#   37,
#   15,
#   5,
#   5,
#   8,
#   21,
#   22,
#   4,
#   4,
#   4,
#   4,
#   23,
#   43,
#   46,
#   50,
#   48,
#   42,
#   39,
#   41,
#   43,
#   45,
#   39,
#   32,
#   11,
#   5,
#   5,
#   5,
#   5,
#   15,
#   21,
#   14,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   38,
#   46,
#   39,
#   39,
#   39,
#   42,
#   44,
#   46,
#   40,
#   25,
#   9,
#   5,
#   5,
#   5,
#   5,
#   15,
#   21,
#   16,
#   4,
#   5,
#   4,
#   20,
#   41,
#   37,
#   41,
#   42,
#   50,
#   42,
#   40,
#   38,
#   38,
#   38,
#   39,
#   41,
#   45,
#   45,
#   39,
#   30,
#   5,
#   10,
#   17,
#   19,
#   4,
#   5,
#   5,
#   22,
#   44,
#   43,
#   41,
#   43,
#   44,
#   43,
#   38,
#   40,
#   40,
#   39,
#   39,
#   42,
#   41,
#   40,
#   38,
#   31,
#   5,
#   4,
#   9,
#   4,
#   15,
#   22,
#   4,
#   21,
#   41,
#   43,
#   39,
#   49,
#   44,
#   42,
#   40,
#   38,
#   41,
#   37,
#   40,
#   39,
#   44,
#   38,
#   36,
#   31,
#   5,
#   13,
#   22,
#   22,
#   4,
#   4,
#   4,
#   23,
#   48,
#   46,
#   45,
#   47,
#   40,
#   41,
#   37,
#   39,
#   39,
#   36,
#   38,
#   40,
#   43,
#   41,
#   37,
#   14,
#   5,
#   17,
#   20,
#   18,
#   4,
#   4,
#   4,
#   22,
#   49,
#   45,
#   40,
#   41,
#   48,
#   43,
#   40,
#   37,
#   39,
#   39,
#   37,
#   38,
#   40,
#   35,
#   15,
#   5,
#   5,
#   4,
#   21,
#   21,
#   4,
#   4,
#   4,
#   4,
#   23,
#   44,
#   42,
#   47,
#   48,
#   41,
#   41,
#   37,
#   39,
#   40,
#   39,
#   30,
#   12,
#   5,
#   5,
#   5,
#   5,
#   13,
#   22,
#   17,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   35,
#   44,
#   41,
#   39,
#   35,
#   40,
#   39,
#   40,
#   38,
#   26,
#   9,
#   5,
#   5,
#   5,
#   5,
#   16,
#   21,
#   16,
#   4,
#   4,
#   4,
#   22,
#   43,
#   38,
#   37,
#   42,
#   48,
#   41,
#   38,
#   36,
#   37,
#   38,
#   36,
#   42,
#   45,
#   49,
#   38,
#   35,
#   5,
#   4,
#   21,
#   15,
#   4,
#   4,
#   4,
#   20,
#   42,
#   37,
#   36,
#   40,
#   46,
#   42,
#   38,
#   38,
#   38,
#   39,
#   38,
#   40,
#   41,
#   46,
#   42,
#   33,
#   5,
#   7,
#   22,
#   11,
#   4,
#   4,
#   4,
#   13,
#   37,
#   41,
#   38,
#   43,
#   48,
#   45,
#   39,
#   37,
#   40,
#   35,
#   38,
#   40,
#   45,
#   44,
#   41,
#   34,
#   5,
#   16,
#   22,
#   16,
#   4,
#   4,
#   4,
#   18,
#   37,
#   37,
#   39,
#   42,
#   48,
#   42,
#   37,
#   38,
#   40,
#   38,
#   36,
#   39,
#   46,
#   43,
#   40,
#   14,
#   7,
#   22,
#   19,
#   14,
#   4,
#   4,
#   4,
#   19,
#   38,
#   41,
#   39,
#   43,
#   50,
#   50,
#   42,
#   42,
#   43,
#   46,
#   41,
#   47,
#   40,
#   43,
#   16,
#   5,
#   5,
#   5,
#   21,
#   21,
#   4,
#   4,
#   4,
#   4,
#   14,
#   40,
#   44,
#   56,
#   58,
#   46,
#   45,
#   43,
#   47,
#   47,
#   43,
#   28,
#   18,
#   5,
#   5,
#   5,
#   5,
#   9,
#   21,
#   20,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   34,
#   44,
#   41,
#   40,
#   38,
#   43,
#   48,
#   47,
#   42,
#   25,
#   9,
#   5,
#   5,
#   5,
#   5,
#   12,
#   21,
#   17,
#   4,
#   4,
#   4,
#   21,
#   42,
#   38,
#   37,
#   45,
#   50,
#   40,
#   38,
#   36,
#   41,
#   40,
#   38,
#   40,
#   46,
#   45,
#   39,
#   31,
#   5,
#   9,
#   17,
#   15,
#   5,
#   5,
#   5,
#   18,
#   40,
#   37,
#   41,
#   47,
#   46,
#   40,
#   39,
#   39,
#   36,
#   38,
#   38,
#   39,
#   43,
#   41,
#   37,
#   32,
#   5,
#   4,
#   9,
#   4,
#   14,
#   22,
#   8,
#   19,
#   41,
#   37,
#   38,
#   43,
#   48,
#   43,
#   41,
#   41,
#   44,
#   45,
#   39,
#   41,
#   46,
#   46,
#   39,
#   30,
#   5,
#   16,
#   23,
#   20,
#   4,
#   4,
#   4,
#   21,
#   44,
#   44,
#   40,
#   38,
#   43,
#   41,
#   40,
#   38,
#   38,
#   40,
#   39,
#   37,
#   43,
#   39,
#   39,
#   14,
#   5,
#   15,
#   19,
#   22,
#   20,
#   20,
#   20,
#   34,
#   43,
#   38,
#   36,
#   44,
#   46,
#   41,
#   38,
#   37,
#   38,
#   43,
#   39,
#   40,
#   39,
#   39,
#   16,
#   5,
#   5,
#   4,
#   22,
#   16,
#   4,
#   4,
#   4,
#   4,
#   24,
#   45,
#   45,
#   45,
#   45,
#   41,
#   37,
#   36,
#   38,
#   41,
#   41,
#   28,
#   10,
#   5,
#   5,
#   5,
#   5,
#   6,
#   22,
#   16,
#   4,
#   5,
#   4,
#   5,
#   5,
#   5,
#   38,
#   45,
#   43,
#   36,
#   37,
#   37,
#   38,
#   42,
#   38,
#   24,
#   9,
#   5,
#   5,
#   5,
#   5,
#   11,
#   22,
#   15,
#   4,
#   4,
#   4,
#   22,
#   45,
#   42,
#   36,
#   41,
#   49,
#   41,
#   39,
#   39,
#   43,
#   42,
#   38,
#   40,
#   44,
#   49,
#   40,
#   31,
#   5,
#   17,
#   22,
#   10,
#   4,
#   4,
#   4,
#   17,
#   38,
#   41,
#   36,
#   42,
#   45,
#   40,
#   41,
#   39,
#   37,
#   39,
#   38,
#   39,
#   43,
#   44,
#   43,
#   32,
#   5,
#   13,
#   22,
#   13,
#   4,
#   4,
#   4,
#   14,
#   37,
#   41,
#   36,
#   40,
#   42,
#   43,
#   39,
#   40,
#   42,
#   43,
#   39,
#   38,
#   45,
#   45,
#   39,
#   30,
#   5,
#   7,
#   21,
#   17,
#   4,
#   4,
#   4,
#   18,
#   38,
#   36,
#   37,
#   41,
#   47,
#   42,
#   42,
#   38,
#   39,
#   ...],
#  5: [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   5,
#   5,
#   5,
#   5,
#   4,
#   23,
#   47,
#   45,
#   46,
#   41,
#   43,
#   43,
#   37,
#   36,
#   35,
#   38,
#   36,
#   36,
#   37,
#   38,
#   14,
#   5,
#   5,
#   5,
#   22,
#   22,
#   6,
#   4,
#   4,
#   4,
#   23,
#   42,
#   52,
#   50,
#   45,
#   43,
#   40,
#   38,
#   39,
#   42,
#   42,
#   28,
#   11,
#   5,
#   5,
#   5,
#   5,
#   13,
#   22,
#   13,
#   5,
#   4,
#   4,
#   5,
#   5,
#   5,
#   42,
#   50,
#   43,
#   37,
#   38,
#   37,
#   40,
#   44,
#   39,
#   26,
#   9,
#   5,
#   5,
#   5,
#   5,
#   17,
#   22,
#   7,
#   4,
#   4,
#   4,
#   22,
#   46,
#   37,
#   38,
#   41,
#   43,
#   44,
#   38,
#   38,
#   37,
#   36,
#   39,
#   38,
#   44,
#   46,
#   38,
#   29,
#   5,
#   10,
#   22,
#   12,
#   4,
#   4,
#   4,
#   22,
#   42,
#   39,
#   38,
#   40,
#   44,
#   41,
#   40,
#   40,
#   39,
#   39,
#   37,
#   40,
#   40,
#   43,
#   36,
#   33,
#   7,
#   6,
#   22,
#   22,
#   12,
#   4,
#   4,
#   22,
#   42,
#   42,
#   39,
#   45,
#   41,
#   41,
#   39,
#   37,
#   40,
#   37,
#   39,
#   40,
#   44,
#   44,
#   36,
#   31,
#   5,
#   15,
#   22,
#   20,
#   4,
#   4,
#   4,
#   22,
#   45,
#   44,
#   39,
#   43,
#   42,
#   44,
#   37,
#   39,
#   35,
#   38,
#   37,
#   40,
#   41,
#   38,
#   38,
#   13,
#   9,
#   22,
#   20,
#   11,
#   4,
#   4,
#   4,
#   22,
#   46,
#   39,
#   38,
#   43,
#   47,
#   43,
#   40,
#   37,
#   39,
#   36,
#   38,
#   38,
#   40,
#   35,
#   15,
#   5,
#   5,
#   4,
#   19,
#   14,
#   4,
#   4,
#   4,
#   4,
#   25,
#   43,
#   41,
#   48,
#   49,
#   42,
#   40,
#   38,
#   43,
#   40,
#   41,
#   30,
#   11,
#   5,
#   5,
#   5,
#   5,
#   4,
#   9,
#   4,
#   4,
#   21,
#   12,
#   4,
#   5,
#   6,
#   31,
#   39,
#   45,
#   39,
#   38,
#   41,
#   40,
#   40,
#   40,
#   28,
#   9,
#   5,
#   5,
#   5,
#   5,
#   17,
#   20,
#   4,
#   4,
#   4,
#   4,
#   19,
#   36,
#   36,
#   37,
#   44,
#   44,
#   43,
#   37,
#   39,
#   41,
#   37,
#   39,
#   43,
#   46,
#   50,
#   42,
#   29,
#   5,
#   11,
#   22,
#   15,
#   4,
#   4,
#   6,
#   18,
#   37,
#   41,
#   37,
#   44,
#   47,
#   47,
#   41,
#   39,
#   40,
#   39,
#   44,
#   42,
#   48,
#   46,
#   43,
#   31,
#   5,
#   9,
#   21,
#   16,
#   4,
#   4,
#   4,
#   11,
#   38,
#   40,
#   39,
#   45,
#   45,
#   47,
#   42,
#   42,
#   45,
#   46,
#   41,
#   42,
#   42,
#   43,
#   39,
#   31,
#   5,
#   8,
#   17,
#   18,
#   4,
#   4,
#   4,
#   18,
#   37,
#   37,
#   40,
#   44,
#   43,
#   43,
#   41,
#   39,
#   43,
#   44,
#   40,
#   41,
#   46,
#   40,
#   39,
#   17,
#   5,
#   4,
#   8,
#   4,
#   5,
#   22,
#   14,
#   22,
#   44,
#   44,
#   39,
#   45,
#   45,
#   42,
#   42,
#   37,
#   41,
#   44,
#   39,
#   40,
#   40,
#   37,
#   15,
#   5,
#   5,
#   8,
#   21,
#   22,
#   4,
#   4,
#   4,
#   4,
#   23,
#   43,
#   46,
#   50,
#   48,
#   42,
#   39,
#   41,
#   43,
#   45,
#   39,
#   32,
#   11,
#   5,
#   5,
#   5,
#   5,
#   15,
#   21,
#   14,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   38,
#   46,
#   39,
#   39,
#   39,
#   42,
#   44,
#   46,
#   40,
#   25,
#   9,
#   5,
#   5,
#   5,
#   5,
#   15,
#   21,
#   16,
#   4,
#   5,
#   4,
#   20,
#   41,
#   37,
#   41,
#   42,
#   50,
#   42,
#   40,
#   38,
#   38,
#   38,
#   39,
#   41,
#   45,
#   45,
#   39,
#   30,
#   5,
#   10,
#   17,
#   19,
#   4,
#   5,
#   5,
#   22,
#   44,
#   43,
#   41,
#   43,
#   44,
#   43,
#   38,
#   40,
#   40,
#   39,
#   39,
#   42,
#   41,
#   40,
#   38,
#   31,
#   5,
#   4,
#   9,
#   4,
#   15,
#   22,
#   4,
#   21,
#   41,
#   43,
#   39,
#   49,
#   44,
#   42,
#   40,
#   38,
#   41,
#   37,
#   40,
#   39,
#   44,
#   38,
#   36,
#   31,
#   5,
#   13,
#   22,
#   22,
#   4,
#   4,
#   4,
#   23,
#   48,
#   46,
#   45,
#   47,
#   40,
#   41,
#   37,
#   39,
#   39,
#   36,
#   38,
#   40,
#   43,
#   41,
#   37,
#   14,
#   5,
#   17,
#   20,
#   18,
#   4,
#   4,
#   4,
#   22,
#   49,
#   45,
#   40,
#   41,
#   48,
#   43,
#   40,
#   37,
#   39,
#   39,
#   37,
#   38,
#   40,
#   35,
#   15,
#   5,
#   5,
#   4,
#   21,
#   21,
#   4,
#   4,
#   4,
#   4,
#   23,
#   44,
#   42,
#   47,
#   48,
#   41,
#   41,
#   37,
#   39,
#   40,
#   39,
#   30,
#   12,
#   5,
#   5,
#   5,
#   5,
#   13,
#   22,
#   17,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   35,
#   44,
#   41,
#   39,
#   35,
#   40,
#   39,
#   40,
#   38,
#   26,
#   9,
#   5,
#   5,
#   5,
#   5,
#   16,
#   21,
#   16,
#   4,
#   4,
#   4,
#   22,
#   43,
#   38,
#   37,
#   42,
#   48,
#   41,
#   38,
#   36,
#   37,
#   38,
#   36,
#   42,
#   45,
#   49,
#   38,
#   35,
#   5,
#   4,
#   21,
#   15,
#   4,
#   4,
#   4,
#   20,
#   42,
#   37,
#   36,
#   40,
#   46,
#   42,
#   38,
#   38,
#   38,
#   39,
#   38,
#   40,
#   41,
#   46,
#   42,
#   33,
#   5,
#   7,
#   22,
#   11,
#   4,
#   4,
#   4,
#   13,
#   37,
#   41,
#   38,
#   43,
#   48,
#   45,
#   39,
#   37,
#   40,
#   35,
#   38,
#   40,
#   45,
#   44,
#   41,
#   34,
#   5,
#   16,
#   22,
#   16,
#   4,
#   4,
#   4,
#   18,
#   37,
#   37,
#   39,
#   42,
#   48,
#   42,
#   37,
#   38,
#   40,
#   38,
#   36,
#   39,
#   46,
#   43,
#   40,
#   14,
#   7,
#   22,
#   19,
#   14,
#   4,
#   4,
#   4,
#   19,
#   38,
#   41,
#   39,
#   43,
#   50,
#   50,
#   42,
#   42,
#   43,
#   46,
#   41,
#   47,
#   40,
#   43,
#   16,
#   5,
#   5,
#   5,
#   21,
#   21,
#   4,
#   4,
#   4,
#   4,
#   14,
#   40,
#   44,
#   56,
#   58,
#   46,
#   45,
#   43,
#   47,
#   47,
#   43,
#   28,
#   18,
#   5,
#   5,
#   5,
#   5,
#   9,
#   21,
#   20,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   34,
#   44,
#   41,
#   40,
#   38,
#   43,
#   48,
#   47,
#   42,
#   25,
#   9,
#   5,
#   5,
#   5,
#   5,
#   12,
#   21,
#   17,
#   4,
#   4,
#   4,
#   21,
#   42,
#   38,
#   37,
#   45,
#   50,
#   40,
#   38,
#   36,
#   41,
#   40,
#   38,
#   40,
#   46,
#   45,
#   39,
#   31,
#   5,
#   9,
#   17,
#   15,
#   5,
#   5,
#   5,
#   18,
#   40,
#   37,
#   41,
#   47,
#   46,
#   40,
#   39,
#   39,
#   36,
#   38,
#   38,
#   39,
#   43,
#   41,
#   37,
#   32,
#   5,
#   4,
#   9,
#   4,
#   14,
#   22,
#   8,
#   19,
#   41,
#   37,
#   38,
#   43,
#   48,
#   43,
#   41,
#   41,
#   44,
#   45,
#   39,
#   41,
#   46,
#   46,
#   39,
#   30,
#   5,
#   16,
#   23,
#   20,
#   4,
#   4,
#   4,
#   21,
#   44,
#   44,
#   40,
#   38,
#   43,
#   41,
#   40,
#   38,
#   38,
#   40,
#   39,
#   37,
#   43,
#   39,
#   39,
#   14,
#   5,
#   15,
#   19,
#   22,
#   20,
#   20,
#   20,
#   34,
#   43,
#   38,
#   36,
#   44,
#   46,
#   41,
#   38,
#   37,
#   38,
#   43,
#   39,
#   40,
#   39,
#   39,
#   16,
#   5,
#   5,
#   4,
#   22,
#   16,
#   4,
#   4,
#   4,
#   4,
#   24,
#   45,
#   45,
#   45,
#   45,
#   41,
#   37,
#   36,
#   38,
#   41,
#   41,
#   28,
#   10,
#   5,
#   5,
#   5,
#   5,
#   6,
#   22,
#   16,
#   4,
#   5,
#   4,
#   5,
#   5,
#   5,
#   38,
#   45,
#   43,
#   36,
#   37,
#   37,
#   38,
#   42,
#   38,
#   24,
#   9,
#   5,
#   5,
#   5,
#   5,
#   11,
#   22,
#   15,
#   4,
#   4,
#   4,
#   22,
#   45,
#   42,
#   36,
#   41,
#   49,
#   41,
#   39,
#   39,
#   43,
#   42,
#   38,
#   40,
#   44,
#   49,
#   40,
#   31,
#   5,
#   17,
#   22,
#   10,
#   4,
#   4,
#   4,
#   17,
#   38,
#   41,
#   36,
#   42,
#   45,
#   40,
#   41,
#   39,
#   37,
#   39,
#   38,
#   39,
#   43,
#   44,
#   43,
#   32,
#   5,
#   13,
#   22,
#   13,
#   4,
#   4,
#   4,
#   14,
#   37,
#   41,
#   36,
#   40,
#   42,
#   43,
#   39,
#   40,
#   42,
#   43,
#   39,
#   38,
#   45,
#   45,
#   39,
#   30,
#   5,
#   7,
#   21,
#   17,
#   4,
#   4,
#   4,
#   18,
#   38,
#   36,
#   37,
#   41,
#   47,
#   ...]}

# %%
type(predictions)
# Out:
# dict

# %%
predictions.keys()
# Out:
# dict_keys([1, 5])

# %%
# predictions[5]
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  5,
#  5,
#  5,
#  5,
#  4,
#  23,
#  47,
#  45,
#  46,
#  41,
#  43,
#  43,
#  37,
#  36,
#  35,
#  38,
#  36,
#  36,
#  37,
#  38,
#  14,
#  5,
#  5,
#  5,
#  22,
#  22,
#  6,
#  4,
#  4,
#  4,
#  23,
#  42,
#  52,
#  50,
#  45,
#  43,
#  40,
#  38,
#  39,
#  42,
#  42,
#  28,
#  11,
#  5,
#  5,
#  5,
#  5,
#  13,
#  22,
#  13,
#  5,
#  4,
#  4,
#  5,
#  5,
#  5,
#  42,
#  50,
#  43,
#  37,
#  38,
#  37,
#  40,
#  44,
#  39,
#  26,
#  9,
#  5,
#  5,
#  5,
#  5,
#  17,
#  22,
#  7,
#  4,
#  4,
#  4,
#  22,
#  46,
#  37,
#  38,
#  41,
#  43,
#  44,
#  38,
#  38,
#  37,
#  36,
#  39,
#  38,
#  44,
#  46,
#  38,
#  29,
#  5,
#  10,
#  22,
#  12,
#  4,
#  4,
#  4,
#  22,
#  42,
#  39,
#  38,
#  40,
#  44,
#  41,
#  40,
#  40,
#  39,
#  39,
#  37,
#  40,
#  40,
#  43,
#  36,
#  33,
#  7,
#  6,
#  22,
#  22,
#  12,
#  4,
#  4,
#  22,
#  42,
#  42,
#  39,
#  45,
#  41,
#  41,
#  39,
#  37,
#  40,
#  37,
#  39,
#  40,
#  44,
#  44,
#  36,
#  31,
#  5,
#  15,
#  22,
#  20,
#  4,
#  4,
#  4,
#  22,
#  45,
#  44,
#  39,
#  43,
#  42,
#  44,
#  37,
#  39,
#  35,
#  38,
#  37,
#  40,
#  41,
#  38,
#  38,
#  13,
#  9,
#  22,
#  20,
#  11,
#  4,
#  4,
#  4,
#  22,
#  46,
#  39,
#  38,
#  43,
#  47,
#  43,
#  40,
#  37,
#  39,
#  36,
#  38,
#  38,
#  40,
#  35,
#  15,
#  5,
#  5,
#  4,
#  19,
#  14,
#  4,
#  4,
#  4,
#  4,
#  25,
#  43,
#  41,
#  48,
#  49,
#  42,
#  40,
#  38,
#  43,
#  40,
#  41,
#  30,
#  11,
#  5,
#  5,
#  5,
#  5,
#  4,
#  9,
#  4,
#  4,
#  21,
#  12,
#  4,
#  5,
#  6,
#  31,
#  39,
#  45,
#  39,
#  38,
#  41,
#  40,
#  40,
#  40,
#  28,
#  9,
#  5,
#  5,
#  5,
#  5,
#  17,
#  20,
#  4,
#  4,
#  4,
#  4,
#  19,
#  36,
#  36,
#  37,
#  44,
#  44,
#  43,
#  37,
#  39,
#  41,
#  37,
#  39,
#  43,
#  46,
#  50,
#  42,
#  29,
#  5,
#  11,
#  22,
#  15,
#  4,
#  4,
#  6,
#  18,
#  37,
#  41,
#  37,
#  44,
#  47,
#  47,
#  41,
#  39,
#  40,
#  39,
#  44,
#  42,
#  48,
#  46,
#  43,
#  31,
#  5,
#  9,
#  21,
#  16,
#  4,
#  4,
#  4,
#  11,
#  38,
#  40,
#  39,
#  45,
#  45,
#  47,
#  42,
#  42,
#  45,
#  46,
#  41,
#  42,
#  42,
#  43,
#  39,
#  31,
#  5,
#  8,
#  17,
#  18,
#  4,
#  4,
#  4,
#  18,
#  37,
#  37,
#  40,
#  44,
#  43,
#  43,
#  41,
#  39,
#  43,
#  44,
#  40,
#  41,
#  46,
#  40,
#  39,
#  17,
#  5,
#  4,
#  8,
#  4,
#  5,
#  22,
#  14,
#  22,
#  44,
#  44,
#  39,
#  45,
#  45,
#  42,
#  42,
#  37,
#  41,
#  44,
#  39,
#  40,
#  40,
#  37,
#  15,
#  5,
#  5,
#  8,
#  21,
#  22,
#  4,
#  4,
#  4,
#  4,
#  23,
#  43,
#  46,
#  50,
#  48,
#  42,
#  39,
#  41,
#  43,
#  45,
#  39,
#  32,
#  11,
#  5,
#  5,
#  5,
#  5,
#  15,
#  21,
#  14,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  38,
#  46,
#  39,
#  39,
#  39,
#  42,
#  44,
#  46,
#  40,
#  25,
#  9,
#  5,
#  5,
#  5,
#  5,
#  15,
#  21,
#  16,
#  4,
#  5,
#  4,
#  20,
#  41,
#  37,
#  41,
#  42,
#  50,
#  42,
#  40,
#  38,
#  38,
#  38,
#  39,
#  41,
#  45,
#  45,
#  39,
#  30,
#  5,
#  10,
#  17,
#  19,
#  4,
#  5,
#  5,
#  22,
#  44,
#  43,
#  41,
#  43,
#  44,
#  43,
#  38,
#  40,
#  40,
#  39,
#  39,
#  42,
#  41,
#  40,
#  38,
#  31,
#  5,
#  4,
#  9,
#  4,
#  15,
#  22,
#  4,
#  21,
#  41,
#  43,
#  39,
#  49,
#  44,
#  42,
#  40,
#  38,
#  41,
#  37,
#  40,
#  39,
#  44,
#  38,
#  36,
#  31,
#  5,
#  13,
#  22,
#  22,
#  4,
#  4,
#  4,
#  23,
#  48,
#  46,
#  45,
#  47,
#  40,
#  41,
#  37,
#  39,
#  39,
#  36,
#  38,
#  40,
#  43,
#  41,
#  37,
#  14,
#  5,
#  17,
#  20,
#  18,
#  4,
#  4,
#  4,
#  22,
#  49,
#  45,
#  40,
#  41,
#  48,
#  43,
#  40,
#  37,
#  39,
#  39,
#  37,
#  38,
#  40,
#  35,
#  15,
#  5,
#  5,
#  4,
#  21,
#  21,
#  4,
#  4,
#  4,
#  4,
#  23,
#  44,
#  42,
#  47,
#  48,
#  41,
#  41,
#  37,
#  39,
#  40,
#  39,
#  30,
#  12,
#  5,
#  5,
#  5,
#  5,
#  13,
#  22,
#  17,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  35,
#  44,
#  41,
#  39,
#  35,
#  40,
#  39,
#  40,
#  38,
#  26,
#  9,
#  5,
#  5,
#  5,
#  5,
#  16,
#  21,
#  16,
#  4,
#  4,
#  4,
#  22,
#  43,
#  38,
#  37,
#  42,
#  48,
#  41,
#  38,
#  36,
#  37,
#  38,
#  36,
#  42,
#  45,
#  49,
#  38,
#  35,
#  5,
#  4,
#  21,
#  15,
#  4,
#  4,
#  4,
#  20,
#  42,
#  37,
#  36,
#  40,
#  46,
#  42,
#  38,
#  38,
#  38,
#  39,
#  38,
#  40,
#  41,
#  46,
#  42,
#  33,
#  5,
#  7,
#  22,
#  11,
#  4,
#  4,
#  4,
#  13,
#  37,
#  41,
#  38,
#  43,
#  48,
#  45,
#  39,
#  37,
#  40,
#  35,
#  38,
#  40,
#  45,
#  44,
#  41,
#  34,
#  5,
#  16,
#  22,
#  16,
#  4,
#  4,
#  4,
#  18,
#  37,
#  37,
#  39,
#  42,
#  48,
#  42,
#  37,
#  38,
#  40,
#  38,
#  36,
#  39,
#  46,
#  43,
#  40,
#  14,
#  7,
#  22,
#  19,
#  14,
#  4,
#  4,
#  4,
#  19,
#  38,
#  41,
#  39,
#  43,
#  50,
#  50,
#  42,
#  42,
#  43,
#  46,
#  41,
#  47,
#  40,
#  43,
#  16,
#  5,
#  5,
#  5,
#  21,
#  21,
#  4,
#  4,
#  4,
#  4,
#  14,
#  40,
#  44,
#  56,
#  58,
#  46,
#  45,
#  43,
#  47,
#  47,
#  43,
#  28,
#  18,
#  5,
#  5,
#  5,
#  5,
#  9,
#  21,
#  20,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  34,
#  44,
#  41,
#  40,
#  38,
#  43,
#  48,
#  47,
#  42,
#  25,
#  9,
#  5,
#  5,
#  5,
#  5,
#  12,
#  21,
#  17,
#  4,
#  4,
#  4,
#  21,
#  42,
#  38,
#  37,
#  45,
#  50,
#  40,
#  38,
#  36,
#  41,
#  40,
#  38,
#  40,
#  46,
#  45,
#  39,
#  31,
#  5,
#  9,
#  17,
#  15,
#  5,
#  5,
#  5,
#  18,
#  40,
#  37,
#  41,
#  47,
#  46,
#  40,
#  39,
#  39,
#  36,
#  38,
#  38,
#  39,
#  43,
#  41,
#  37,
#  32,
#  5,
#  4,
#  9,
#  4,
#  14,
#  22,
#  8,
#  19,
#  41,
#  37,
#  38,
#  43,
#  48,
#  43,
#  41,
#  41,
#  44,
#  45,
#  39,
#  41,
#  46,
#  46,
#  39,
#  30,
#  5,
#  16,
#  23,
#  20,
#  4,
#  4,
#  4,
#  21,
#  44,
#  44,
#  40,
#  38,
#  43,
#  41,
#  40,
#  38,
#  38,
#  40,
#  39,
#  37,
#  43,
#  39,
#  39,
#  14,
#  5,
#  15,
#  19,
#  22,
#  20,
#  20,
#  20,
#  34,
#  43,
#  38,
#  36,
#  44,
#  46,
#  41,
#  38,
#  37,
#  38,
#  43,
#  39,
#  40,
#  39,
#  39,
#  16,
#  5,
#  5,
#  4,
#  22,
#  16,
#  4,
#  4,
#  4,
#  4,
#  24,
#  45,
#  45,
#  45,
#  45,
#  41,
#  37,
#  36,
#  38,
#  41,
#  41,
#  28,
#  10,
#  5,
#  5,
#  5,
#  5,
#  6,
#  22,
#  16,
#  4,
#  5,
#  4,
#  5,
#  5,
#  5,
#  38,
#  45,
#  43,
#  36,
#  37,
#  37,
#  38,
#  42,
#  38,
#  24,
#  9,
#  5,
#  5,
#  5,
#  5,
#  11,
#  22,
#  15,
#  4,
#  4,
#  4,
#  22,
#  45,
#  42,
#  36,
#  41,
#  49,
#  41,
#  39,
#  39,
#  43,
#  42,
#  38,
#  40,
#  44,
#  49,
#  40,
#  31,
#  5,
#  17,
#  22,
#  10,
#  4,
#  4,
#  4,
#  17,
#  38,
#  41,
#  36,
#  42,
#  45,
#  40,
#  41,
#  39,
#  37,
#  39,
#  38,
#  39,
#  43,
#  44,
#  43,
#  32,
#  5,
#  13,
#  22,
#  13,
#  4,
#  4,
#  4,
#  14,
#  37,
#  41,
#  36,
#  40,
#  42,
#  43,
#  39,
#  40,
#  42,
#  43,
#  39,
#  38,
#  45,
#  45,
#  39,
#  30,
#  5,
#  7,
#  21,
#  17,
#  4,
#  4,
#  4,
#  18,
#  38,
#  36,
#  37,
#  41,
#  47,
#  ...]

# %%
inputs[2]
# Out:
# 0.0517051705170517

# %%
for n in predictions:
    print(n)
# Out:
# 1
# 5

# %% [markdown]
# - this loop sort of makes sense, so the problem is that i'm giving it 0s where it doesn't expect them
#
#
# - for idx, inp in enumerate(inputs): iterate counter,float through list of floats
#     - for n in predictions: there's 2 values here, 1 and 5 ints.
#         - val = predictions[1 or 5][counter]
#         - if not math.isnan(val): # if val isn't nan, because some are nan
#             - accuracy[1 or 5] += (consumption - predicted_consumption) ** 2
#             - accuracy_samples[1 or 5] += 1
#     - for n in sorted(predictions): # for 1 and 5 in predictions:
#         - accuracy[n] = (accuracy[n] / accuracy_samples[n]) ** 5
#         - readjust the accuracy based on sample size for RMS

# %%
inputs[:5]
# Out:
# array([0.23322332, 0.18041804, 0.05170517, 0.05170517, 0.05060506])

# %% [markdown]
# ## alright, what's going on with division by 0 ?
# - accuracy and accuracy_samples are both dicts where all values are 0
#     - and we're telling it to divide by the square root of these 0s. cool.
#     - something is hilariously wrong here.
# - both these dicts are supposed to be modified in a loop-through-predictions
#     - so it's not supposed to be dividing be 0. makes more sense
# - the accuracy cell ran perfectly before i used the "shift alignment" loop that inserts a bunch of zeroes
#     - however, RMSE is the same between 1 and 5, so something smells fishy

# %%
acc_lists = {1: [], 5: []} # i added this one for graphing
# calculate predictive accuracy, RMS
accuracy         = {1: 0, 5: 0}
accuracy_samples = {1: 0, 5: 0}
for idx, inp in enumerate(inputs):
    for n in predictions: # for each [N]umber of timesteps ahead which was predicted
        val = predictions[n][idx]
        if not math.isnan(val):
            accuracy[n] += (inp - val) ** 2 # RMSE
            accuracy_samples[n] += 1
    for n in sorted(predictions):
#         print("accuracy[n]: ",accuracy[n], "    accuracy_samples[n]:  ",accuracy_samples[n])
        accuracy[n] = (accuracy[n] / accuracy_samples[n]) ** .5
#         print("Predictive Error (root-mean-squared): ", n, "steps ahead:", accuracy[n])
#         print()
        acc_lists[n].append(accuracy[n]) # add to lists
        
    print('Anomaly Mean: ', np.mean(anomaly))
    print('Anomaly Std: ', np.std(anomaly))
# Out:
# Predictive Error (root-mean-squared):  1 steps ahead: 13.2
#
# Predictive Error (root-mean-squared):  5 steps ahead: 8.2
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 8.460496439334987
#
# Predictive Error (root-mean-squared):  5 steps ahead: 28.07454362941631
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.6882433117824958
#
# Predictive Error (root-mean-squared):  5 steps ahead: 28.62728618893413
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.7732909597541018
#
# Predictive Error (root-mean-squared):  5 steps ahead: 29.770443757983077
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 25.22987630155865
#
# Predictive Error (root-mean-squared):  5 steps ahead: 29.349379699605183
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 13.425596673900932
#
# Predictive Error (root-mean-squared):  5 steps ahead: 12.646471047289603
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.820222804620254
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.3573330493123852
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 9.776120286216692
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4355073261887198
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.779860671832828
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6425052785858916
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 4.000373240984306
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.047827181429188
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6149924789624597
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.351166580491658
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.6654423097452717
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.9775712499240568
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 4.515830635832003
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.25935182503736
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.890242653429144
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.180049143807466
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.9831331273544706
#
# Predictive Error (root-mean-squared):  5 steps ahead: 6.656676093185485
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.8078301984804495
#
# Predictive Error (root-mean-squared):  5 steps ahead: 8.499509824444235
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4841878388826273
#
# Predictive Error (root-mean-squared):  5 steps ahead: 7.600075502041544
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.688150604291794
#
# Predictive Error (root-mean-squared):  5 steps ahead: 7.476481924831735
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 6.255642297807686
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.543091735853781
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 7.444782207351025
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.75911279408176
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.0731248808932423
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.8271901029296987
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.30771333183022226
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.19507458980531928
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.0489687136676136
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.09209508078382417
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.275402608273127
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.19387443109564337
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.3197017274492264
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.90133675695253
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.4059320520767047
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.124865034238397
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4039587461553884
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.4754422315687816
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13282087106800597
#
# Predictive Error (root-mean-squared):  5 steps ahead: 7.812913856996104
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3047226478386424
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.151407286320079
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5928665574376369
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.07427460736395
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17532150719488215
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5911791008398429
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6055813711631491
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.725752069961838
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.4841875770189854
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.014087888658846
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 4.094200301060811
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.2424304967318913
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.28017508374634
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.287298285123267
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.783084694901137
#
# Predictive Error (root-mean-squared):  5 steps ahead: 6.276161464632847
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.9429226013913499
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.71949289347435
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.0625555415995827
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.270272870428593
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.190822398377843
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.440777359783153
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 5.825441662222654
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.830267526794509
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 5.666042283860335
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.821889450079434
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.5065450445724666
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.660542145151516
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.900472034411674
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.0479275465939906
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17776849311877477
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.578751154457792
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08663698121328188
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.12812764073877375
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07322344914463241
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.07914318899239778
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07044289208735316
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.07133129016977797
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6794673602058844
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.8236267774576077
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.4599629471251574
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.3179143808801417
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.222374434836766
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.8070677094380637
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.20874857918205053
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.182563276212821
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13996899238911475
#
# Predictive Error (root-mean-squared):  5 steps ahead: 6.5392197889059736
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13388033183640088
#
# Predictive Error (root-mean-squared):  5 steps ahead: 6.204911657329408
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.4499957684462186
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.453855095348762
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 4.966597510585447
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.1066691779126145
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 6.20760851914606
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.606801394944514
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.9966400441126568
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7085542655857264
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7081622652076365
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.4878737100281247
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.12743640921396746
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.2517017912041786
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3772142717610677
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6358944067375255
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11923349951217237
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.3737939235463037
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.24525278267837566
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.3180440067945063
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.25958614139514197
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.415553397891555
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.270115315114303
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.89455302063856
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4030741814651373
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.263231986362961
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.8643915011113248
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6096360827981098
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6214378068461727
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.427062791754871
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10719949838324892
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.014604992634868
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07195001267821231
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9189203257685893
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.04809960093065998
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.12005476879732786
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.9141924751950482
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.15966755818885228
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5076387669505179
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.62702722932803
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.0382225629174116
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.16498348731520185
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.47188842249271984
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.557152061539175
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11324830668301226
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.659967313278122
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08909252336483305
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.7439018574449285
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.08575593610057
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.14420876137881
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.7336829574771997
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.2875196755812888
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2511664675040153
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.42897463374862055
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.963140478250084
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.08580316382195789
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.468381236393435
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.689657305879781
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.362871704662861
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.25968220037895556
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13939938741904698
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6062891492800165
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7757438779235974
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.8878564954648066
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.30804399758177425
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.31017749179660536
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4247850892685668
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21350283184758276
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07069320873823501
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.050685284523356466
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.06995885225179908
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.409287628788481
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3826277983207351
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.67128132980444
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17103046506789807
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.536981263622985
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7141507710504515
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.176829047615768
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 3.4311934651572042
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6047340451895917
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.4133838142966857
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.446744972247253
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.9216854578058699
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.565082108453648
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.7059699678290938
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.16936668747374106
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.1609800545939135
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.2787503117986623
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.7396853017188
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.9500603548981537
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.8988637118420781
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.4605503578378416
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11844376886203518
#
# Predictive Error (root-mean-squared):  5 steps ahead: 4.054615215907555
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.06916962981410517
#
# Predictive Error (root-mean-squared):  5 steps ahead: 6.842963258133064
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.831055448570778
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.631276353164383
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.449331752500979
#
# Predictive Error (root-mean-squared):  5 steps ahead: 5.320439017298829
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2906192209363988
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.23255522399375325
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6884390036450383
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.20173657671467343
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2849968922745353
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21912676428463537
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2768590148036749
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5071110068298346
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05441782064519557
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7957075908631818
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.29914102057584696
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21954725279924636
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.24512009826631992
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.24362603416115858
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.28990782388179115
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3842776698993623
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2986442009711722
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6575567503333861
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05249525497019201
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.12913022048406175
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07828330979625558
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7721314610230756
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3008508884870977
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.353987063681419
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5525502211169673
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.8120300373553153
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5153049835234584
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.002287549618314
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7333642475041269
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.305719917516203
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.615620230182159
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.710096814703064
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3124263977885739
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.31369439732559956
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4067469163457365
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.24279096628797095
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.9335206041201806
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.04834372165925506
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.7133600403600593
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.7293473224465192
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7309274654011327
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.437393895664284
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09922796600306746
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.9937130277812147
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.565501141401061
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.1789856407700636
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.7318801168722586
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.9130690576587115
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3401236472350064
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.18767263040208376
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4361597654461303
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.2591704408782302
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0785606843624048
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.06928037860405482
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.14246620879682875
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5793184349441896
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.06948371267205991
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.24509413108268654
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.1411394032742329
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4026907051613606
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05423004489191573
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.07005318630146436
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.15679223930145098
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.24296141187226838
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10062001271013907
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.25317189902971665
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.027200239606175815
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.0959921833149525
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.02214752125758786
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5815659214965181
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.015262799631496786
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.8184068450737683
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.15303318866141813
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.294052201371472
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7022567356573753
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.8909257978215164
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3277070211976709
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.251753169984446
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 2.031387001050416
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.613961431136777
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.1366785571308592
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.14613820049635592
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5675035398637204
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9338768439819402
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0974680686833038
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.10966648008871191
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7122098932037402
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.7712886464497262
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09590988873149643
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.0701672810531546
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0705149921155115
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.814909829194108
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4092468239046483
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.29617931134593
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.5869661765433747
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.5096493617423128
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2874524570715061
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3639340723512445
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4401513828777033
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.44072259798055713
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4238028227464139
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.23264214992438803
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.18487979286563938
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5011197989718498
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10998181060361407
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.42948671389546084
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4091891748778342
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.41168421052019677
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08812227950818495
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1752465817019489
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05325614479956819
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3674686465717906
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09690999989939361
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6520768400459804
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.06786521568057662
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.18527136921361448
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.22162395008814884
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.48980457104972264
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3008385805440417
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.7661197636282626
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2388731031109211
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.0406394399068253
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.1683650415439352
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.2621377515556182
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5769741606605647
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.4351056085129015
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6855521658139314
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7662893914028719
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4303984518329535
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.43095972408202543
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05061517111128563
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.3896534334229875
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.017306012074216656
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1785817472040621
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5753122221995647
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.5695371312945063
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0789296904609081
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.007845041901168
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05751287471943698
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6186915837319837
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.3078188895373657
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.9068970123429545
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.6852091839347514
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.4612758104902066
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.18662734731368144
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.18316699344727888
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03256351724232767
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.15416872017679348
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.36855622663008925
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.030454997843608562
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13530149908713235
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6522237458070868
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.23333029193519866
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6828392244160825
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4709525235091535
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4735964012181214
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.1362673786070104
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.07296394330972361
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17266920954939266
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.27499214717369
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08005016219523244
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.08346957651225337
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.042352696271852966
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.11261394173169326
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09676811783070116
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.8896626524926552
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.1847225195682674
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.165392093244667
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17110403564420676
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.3425480445166693
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.5537550671519094
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9736762646392777
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.7330221383981224
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5142090873634887
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0625351327948884
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.083483660152388
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.028259746295857317
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.09636002680155162
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.2413623643046205
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.026649736826557
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.21691862761588668
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.0941830409642694
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6757085575760642
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6219945595983287
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07731747928479159
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.06042560841055968
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.053800343262162265
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6643435704254435
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.02182072121693552
#
# Predictive Error (root-mean-squared):  5 steps ahead: 3.222465827277569
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.017669914112185093
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.717751657130345
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4461483585529138
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.8305648367380964
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.15899918802548818
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4221407634707769
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6072489108606293
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.313717405898264
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.40478113454736103
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6133971199491182
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.8994929637277878
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4107748122800254
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.3356986639226467
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.2629095760109082
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2753773345963293
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.0412771463413264
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.13733555629301633
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.028739238731446
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.043257210523623725
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.6777656155785086
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0981378840273396
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.457169421399247
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.0654606521871104
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.520174264329835
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.4715645393871937
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.7492994165887559
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.4755219857739931
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3693808026005202
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.04785601368797594
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.1614470902320488
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.014989200132122661
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.15566677861229974
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.00836916909087164
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.07348681548135139
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.8047775054911817
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.08390157066693317
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.1719024922809538
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.05789124424725262
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.25519399408843113
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.29913771040970055
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03979269642131633
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.042249678920103485
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05571423731297719
#
# Predictive Error (root-mean-squared):  5 steps ahead: 2.581354153916172
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 1.1934398606878753
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.3057066253981826
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# ...
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.10957510221080209
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.019087504450434632
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21610481376618884
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09434249439983834
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21005509730796929
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.01591234735461953
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21306800945637952
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.013822110534023484
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.21456510357216993
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03350418709433878
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7330342206321936
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2509097915814903
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7527956426471831
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.415137993698723
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.11781136693489208
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.38626019087847513
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.008012749358645103
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11287932577881835
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.05473852471627539
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.02484825429865536
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.355667163368142
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2021334525066048
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.33901285415190907
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0626736948265086
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.2599881943460053
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.14894417089031617
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1642717976349962
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08679080293181751
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.284151037465451
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.02620774799805646
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3145356269158121
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11545627626786688
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4040951090061628
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09429708915509807
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6257549121873642
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.37812697411292895
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7578101155938279
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.11879420215320845
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.619604011415809
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.47368132947196967
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5041564057869965
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5587002859520656
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.49800157227875974
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.30528203442886165
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.30525913235824487
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.058274912798195
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.04928147735423611
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07747493695411305
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.18060409890917198
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17605082749620377
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.22161127478765283
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10184268970851428
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5204034044858002
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.015922634874904633
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5916897273158157
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.015287465789894044
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6067998416169553
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03190259246699915
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9266841501952017
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.5822925297107331
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9008422879788869
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08719418483419078
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.14173866375070077
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0835012859974905
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.009488633606596127
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.24409077860482054
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.02883893148365871
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08520740062192607
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4031773754551553
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.18039868532917255
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3320338548907743
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2894987150449975
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.35014906907655174
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.15778649858490826
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.06726683885824307
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08202982951701764
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1454909197188843
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.027609475154231167
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.04881686685102532
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.08182873339695197
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1575570677858657
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.006277759150638782
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.43469053556846043
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03182256240321624
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.7859761260096197
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10148126060787219
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6920780488537281
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.19989768254926002
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5179191245598922
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.17270154718536113
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3846498756516222
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10764872399212616
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.1380560918887496
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07583350969021477
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.151445966994481
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0073487108778575285
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.26336996504097965
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.16644262554599468
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.22709311819748282
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.00635492944892027
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6642003252979721
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.001934566304020085
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.682349253320419
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.015140118580902634
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.6656390528804543
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.03181437799853825
#
# Predictive Error (root-mean-squared):  5 steps ahead: 1.0148796501390895
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.6154727665472354
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.9331539676730625
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.16372958901440668
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.139871547616278
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10147903889292544
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.03522944076476383
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.26761160046185967
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.049966235036120285
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05048906712470639
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.3521986058280645
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.19801463707954597
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4701122497018572
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.26756111561808144
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.34319140544903115
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.15431951163165483
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.0491554040318693
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.05170968665588372
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.0997705143626424
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.024413287372499485
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.021680696594654134
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.025786347668325514
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.23111376153891375
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.10121951008397384
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5633906399431334
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.09073527034148085
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.5890609403788649
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.2355978004800748
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.4621933328305279
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.02960725288515522
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.24329260353579318
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.0830695407421266
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.09840720170859771
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.006279535647815205
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.0861685483748512
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.016645024536876333
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.004680414004789568
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016
# Predictive Error (root-mean-squared):  1 steps ahead: 0.07548016042175423
#
# Predictive Error (root-mean-squared):  5 steps ahead: 0.0010324295266877848
#
# Anomaly Mean:  0.008881803730087437
# Anomaly Std:  0.06160533288492016

# %% [markdown]
# ## 1,5 deviation _does_ occur, but only at the beginning
# - we should graph this

# %%
# acc_lists[1]

# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(30,19)})

df = pd.DataFrame({'time_1': acc_lists[1], 'time_5': acc_lists[5]})
# g = sns.factorplot(data=df)

# %% [markdown]
# # pre-fix graphs:

# %%
df['difference'] = df['time_5']-df['time_1']
sns.lineplot(data=df)

# %%
sns.lineplot(data=df.drop(columns=['time_5', 'time_1']))

# %% [markdown]
# ## so the accuracy of 5-steps and 1-step versions almost immediately converges.
# - this is a good hint that i've done something terrifically wrong

# %%
sns.regplot(data = df_comments.reset_index(), x = 'index', y = 'score')

# %%
sns.regplot(data = df.reset_index(), x='index', y)

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2,1,1)
plt.title("Predictions")
plt.xlabel("Time")
plt.ylabel("Power Consumption")
plt.plot(np.arange(len(inputs)), inputs, 'red',
       np.arange(len(inputs)), predictions[1], 'blue',
       np.arange(len(inputs)), predictions[5], 'green',)
plt.legend(labels=('Input', '1 Step Prediction, Shifted 1 step', '5 Step Prediction, Shifted 5 steps'))
# the syntax error was a missing parantheses
# good reminder that syntax error on line N usually means you forgot something on line N-1
plt.subplot(2,1,2)
plt.title("Anomaly Score")
plt.xlabel("Time")
plt.ylabel("Power Consumption")
inputs = np.array(inputs) / max(inputs)
plt.plot(np.arange(len(inputs)), inputs, 'red',
       np.arange(len(inputs)), anomaly, 'blue',)
plt.legend(labels=('Input', 'Anomaly Score'))
plt.show()

# %% [markdown]
# ## the top graph "input" is _way_ below predicted values
# - oh, they get normalized at some point in the process, i forgot. let's look at where

# %%
inputs
# Out:
# array([0.23322332, 0.18041804, 0.05170517, ..., 0.05830583, 0.05610561,
#        0.0550055 ])

# %% [markdown]
# # post-fix graphs

# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(30,19)})

df = pd.DataFrame({'time_1': acc_lists[1], 'time_5': acc_lists[5]})

# %%
df['difference'] = df['time_5']-df['time_1']
sns.set(rc={'figure.figsize':(30,19)})
sns.lineplot(data=df)

# %%
sns.set(rc={'figure.figsize':(30,19)})

sns.lineplot(data=df.drop(columns=['time_5', 'time_1']))

# %% [markdown]
# ## looks much better

# %%
import matplotlib.pyplot as plt
plt.subplot(2,1,1)
plt.title("Predictions")
plt.xlabel("Time")
plt.ylabel("Power Consumption")
plt.plot(np.arange(len(inputs)), inputs, 'red',
       np.arange(len(inputs)), predictions[1], 'blue',
       np.arange(len(inputs)), predictions[5], 'green',)
plt.legend(labels=('Input', '1 Step Prediction, Shifted 1 step', '5 Step Prediction, Shifted 5 steps'))
# the syntax error was a missing parantheses
# good reminder that syntax error on line N usually means you forgot something on line N-1
plt.subplot(2,1,2)
plt.title("Anomaly Score")
plt.xlabel("Time")
plt.ylabel("Power Consumption")
inputs = np.array(inputs) / max(inputs)
plt.plot(np.arange(len(inputs)), inputs, 'red',
       np.arange(len(inputs)), anomaly, 'blue',)
plt.legend(labels=('Input', 'Anomaly Score'))
plt.show()

# %% [markdown]
# blimey, it's actually predicting anomalies now.
# # takeaways:
# - got it to work by adding an altered copy of the original training loop immediately prior to original loop
#     - runs through each data-SDR & label, computes in pooler & temporal mem, calls predictor.learn()
#     - does not call predictor.infer() like the original loop
#         - the original loop does this at each iteration to form anomaly predictions
# - i wonder if my workaround messed with the results somehow?

# %% [markdown]
# # end of document, only code scraps below

# %%
print("Encoded Input", enc_info)
print("")
print("Spatial Pooler Mini-Columns", sp_info)
print(str(sp))
print("")
print("Temporal Memory Cells", tm_info)
print(str(tm))
print(""
# Shift the predictions so that they are aligned with the input they predict.
for n_steps, pred_list in predictions.items():
  for x in range(n_steps):
      pred_list.insert(0, float('nan'))
      pred_list.pop(
# Calculate the predictive accuracy, Root-Mean-Squared
accuracy         = {1: 0, 5: 0}
accuracy_samples = {1: 0, 5: 0
for idx, inp in enumerate(inputs):
  for n in predictions: # For each [N]umber of time steps ahead which was predicted.
    val = predictions[n][ idx ]
    if not math.isnan(val):
      accuracy[n] += (inp - val) ** 2
      accuracy_samples[n] += 1
for n in sorted(predictions):
  accuracy[n] = (accuracy[n] / accuracy_samples[n]) ** .5
  print("Predictive Error (RMS)", n, "steps ahead:", accuracy[n]
# Show info about the anomaly (mean & std)
print("Anomaly Mean", np.mean(anomaly))
print("Anomaly Std ", np.std(anomaly)
# Plot the Predictions and Anomalies.
if verbose:
  try:
    import matplotlib.pyplot as plt
  except:
    print("WARNING: failed to import matplotlib, plots cannot be shown.")
    return -accuracy[5
  plt.subplot(2,1,1)
  plt.title("Predictions")
  plt.xlabel("Time")
  plt.ylabel("Power Consumption")
  plt.plot(np.arange(len(inputs)), inputs, 'red',
           np.arange(len(inputs)), predictions[1], 'blue',
           np.arange(len(inputs)), predictions[5], 'green',)
  plt.legend(labels=('Input', '1 Step Prediction, Shifted 1 step', '5 Step Prediction, Shifted 5 steps')
  plt.subplot(2,1,2)
  plt.title("Anomaly Score")
  plt.xlabel("Time")
  plt.ylabel("Power Consumption")
  inputs = np.array(inputs) / max(inputs)
  plt.plot(np.arange(len(inputs)), inputs, 'red',
           np.arange(len(inputs)), anomaly, 'blue',)
  plt.legend(labels=('Input', 'Anomaly Score'))
  plt.show(
return -accuracy[5]

# %%
len(records)
# Out:
# 4391

# %% [markdown]
# ## ah, we're still stuck at the same error as before
# ### something's written wrong, i think - or i've installed something wrong
# - i can't find anything in the nupic docs regarding predictor.infer
# - SDRClassifier.infer() needs a list of active indices from output + dict of classification label

# %% [markdown]
# ### some progress:
# - I realized there's a predictor.learn() at the bottom using count, tm.getActiveCells(), and int(consumption/predictor_resolution))
#     - this answers a lot of my questions
#     - now i wonder: why doesn't it work when i copy this line and put it before predictor.infer()?
#
#
# - i'm going off johan's example a lot here

# %%
type(predictor)
# Out:
# htm.bindings.algorithms.Predictor

# %%
predictor.learn()

# %%
help(predictor)
# Out:
# Help on Predictor in module htm.bindings.algorithms object:
#
# class Predictor(pybind11_builtins.pybind11_object)
#  |  The Predictor class does N-Step ahead predictions.
#  |
#  |  Internally, this class uses Classifiers to associate SDRs with future values.
#  |  This class handles missing datapoints.
#  |
#  |  Compatibility Note:  This class is the replacement for the old SDRClassifier.
#  |  It no longer provides estimates of the actual value.
#  |
#  |  Example Usage:
#  |      # Predict 1 and 2 time steps into the future.
#  |
#  |      # Make a sequence of 4 random SDRs, each SDR has 1000 bits and 2% sparsity.
#  |      sequence = [ SDR( 1000 ).randomize( 0.02 ) for i in range(4) ]
#  |
#  |      # Make category labels for the sequence.
#  |      labels = [ 4, 5, 6, 7 ]
#  |
#  |      # Make a Predictor and train it.
#  |      pred = Predictor([ 1, 2 ])
#  |      pred.learn( 0, sequence[0], labels[0] )
#  |      pred.learn( 1, sequence[1], labels[1] )
#  |      pred.learn( 2, sequence[2], labels[2] )
#  |      pred.learn( 3, sequence[3], labels[3] )
#  |
#  |      # Give the predictor partial information, and make predictions
#  |      # about the future.
#  |      pred.reset()
#  |      A = pred.infer( sequence[0] )
#  |      numpy.argmax( A[1] )  ->  labels[1]
#  |      numpy.argmax( A[2] )  ->  labels[2]
#  |
#  |      B = pred.infer( sequence[1] )
#  |      numpy.argmax( B[1] )  ->  labels[2]
#  |      numpy.argmax( B[2] )  ->  labels[3]
#  |
#  |  Method resolution order:
#  |      Predictor
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(...)
#  |      __init__(self: htm.bindings.algorithms.Predictor, steps: List[int], alpha: float=0.001) -> None
#  |
#  |      Argument steps is the number of steps into the future to learn and predict.
#  |      The Predictor accepts a list of steps.
#  |
#  |      Argument alpha is used to adapt the weight matrix during learning.
#  |      A larger alpha results in faster adaptation to the data.
#  |
#  |  infer(...)
#  |      infer(self: htm.bindings.algorithms.Predictor, pattern: htm.bindings.sdr.SDR) -> Dict[int, List[float]]
#  |
#  |      Compute the likelihoods.
#  |
#  |      Argument pattern is the SDR containing the active input bits.
#  |
#  |      Returns a dictionary whos keys are prediction steps, and values are PDFs.
#  |      See help(Classifier.infer) for details about PDFs.
#  |
#  |  learn(...)
#  |      learn(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. learn(self: htm.bindings.algorithms.Predictor, recordNum: int, pattern: htm.bindings.sdr.SDR, classification: List[int]) -> None
#  |
#  |      Learn from example data.
#  |
#  |      Argument recordNum is an incrementing integer for each record.
#  |      Gaps in numbers correspond to missing records.
#  |
#  |      Argument pattern is the SDR containing the active input bits.
#  |
#  |      Argument classification is the current category or bucket index.
#  |      This may also be a list for when the input has multiple categories.
#  |
#  |      2. learn(self: htm.bindings.algorithms.Predictor, recordNum: int, pattern: htm.bindings.sdr.SDR, classification: int) -> None
#  |
#  |  reset(...)
#  |      reset(self: htm.bindings.algorithms.Predictor) -> None
#  |
#  |      For use with time series datasets.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# ## why do we call predictor.infer(tm_SDR), then predictor.learn(count, TM_SDR, consumption/predictor_resolution) at each iteration?
# ### because we're trying to make a prediction on each round to see how well we grow over time
# #### makes sense. but
# - predictor_resolution is just set to 1.
#     - so for each data iteration:
#     - we tell the predictor
#         - "assosciate this TM_SDR_output with this consumption level"
#             - nevermind for now that consumption is a float and Predictor seems to only want ints
#         - this makes sense. but why is is giving me an error of "must call learn before infer"?
#         - perhaps it's got nothing to make an inference with since there's no prior training?

# %%
inputs = []
anomaly = []
anomalyProb = []
predictions = {1: [], 5:[]}
for count, record in enumerate(records): # iterate through listified CSV
    dateString = datetime.datetime.strptime(record[0], "%m/%d/%y %H:%M") # unstring it
    consumption = float(record[1]) # unstring the power value
    inputs.append(consumption) # add power to input
    
    # use encoder: create SDRs for each input value
    dateBits = dateEncoder.encode(dateString)
    consumptionBits = scalarEncoder.encode(consumption)
    
    # concatenate these encoded_SDRs into a larger one for pooling
    encoding = SDR(encodingWidth).concatenate([consumptionBits, dateBits])
    enc_info.addData(encoding) # enc_info is our metrics to keep track of how the encoder fares
    
    # create SDR to represent active columns. it'll be populated by .compute()
    # notably, this activeColumns SDR has same dimensions as spatial pooler
    activeColumns = SDR(sp.getColumnDimensions())
    
    # throw the input into the spatial pool and hope it swims
    sp.compute(encoding, True, activeColumns) # we're training, so learn=True
    tm_info.addData(tm.getActiveCells().flatten())
    
    
    tm.compute(activeColumns, learn=True)
    
    # make prediction, then train the predictor accordingly
#     predictor.learn(activeColumns)
    pdf = predictor.infer( tm.getActiveCells() )
    for n in (1,5):
        if pdf[n]:
            predictions[n].append( np.argmax( pdf[n] ) * predictor_resolution )
        else:
            predictions[n].append(float('nan'))
    
    anomalyLikelihood = anomaly_history.anomalyProbability( consumption, tm.anomaly )
    anomaly.append(tm.anomaly)
    anomalyProb.append(anomalyLikelihood)
    
    predictor.learn(count, tm.getActiveCells(), int(consumption/predictor_resolution))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-a044384c641d> in <module>
#      28
#      29     # make prediction, then train the predictor accordingly
# ---> 30     pdf = predictor.infer( tm.getActiveCells() )
#      31     for n in (1,5):
#      32         if pdf[n]:
#
# RuntimeError: CHECK FAILED: "dimensions_ != 0" Classifier: must call `learn` before `infer`.

# %%
for n in (1,5):
    print(n)
# Out:
# 1
# 5

# %% [markdown]
# ## post-training

# %%
# Print information & statistics about the state of the HTM.
print("Encoded Input", enc_info)
print("")
print("Spatial Pooler Mini-Columns", sp_info)
print(str(sp))
print("")
print("Temporal Memory Cells", tm_info)
print(str(tm))
print(""
# Shift the predictions so that they are aligned with the input they predict.
for n_steps, pred_list in predictions.items():
  for x in range(n_steps):
      pred_list.insert(0, float('nan'))
      pred_list.pop(
# Calculate the predictive accuracy, Root-Mean-Squared
accuracy         = {1: 0, 5: 0}
accuracy_samples = {1: 0, 5: 0
for idx, inp in enumerate(inputs):
  for n in predictions: # For each [N]umber of time steps ahead which was predicted.
    val = predictions[n][ idx ]
    if not math.isnan(val):
      accuracy[n] += (inp - val) ** 2
      accuracy_samples[n] += 1
for n in sorted(predictions):
  accuracy[n] = (accuracy[n] / accuracy_samples[n]) ** .5
  print("Predictive Error (RMS)", n, "steps ahead:", accuracy[n]
# Show info about the anomaly (mean & std)
print("Anomaly Mean", np.mean(anomaly))
print("Anomaly Std ", np.std(anomaly)
# Plot the Predictions and Anomalies.
if verbose:
  try:
    import matplotlib.pyplot as plt
  except:
    print("WARNING: failed to import matplotlib, plots cannot be shown.")
    return -accuracy[5
  plt.subplot(2,1,1)
  plt.title("Predictions")
  plt.xlabel("Time")
  plt.ylabel("Power Consumption")
  plt.plot(np.arange(len(inputs)), inputs, 'red',
           np.arange(len(inputs)), predictions[1], 'blue',
           np.arange(len(inputs)), predictions[5], 'green',)
  plt.legend(labels=('Input', '1 Step Prediction, Shifted 1 step', '5 Step Prediction, Shifted 5 steps')
  plt.subplot(2,1,2)
  plt.title("Anomaly Score")
  plt.xlabel("Time")
  plt.ylabel("Power Consumption")
  inputs = np.array(inputs) / max(inputs)
  plt.plot(np.arange(len(inputs)), inputs, 'red',
           np.arange(len(inputs)), anomaly, 'blue',)
  plt.legend(labels=('Input', 'Anomaly Score'))
  plt.show(
return -accuracy[5]
